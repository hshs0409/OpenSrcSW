# %%
x = int(input())
y = 3 * (x ** 2) + 5*x + 3
print(f"x:{x} y = 3x^2 + 5x + 3 = {y}")
# Out:
# 10
# x:10 y = 3x^2 + 5x + 3 = 353

# %%
pi = 3.14
r = int(input())
print(f"원의 둘레 : 2πr :{round(2*pi*r,2)} 원의 넓이 πr^2 : {round(pi*(r**2))}")
# Out:
# 50
# 원의 둘레 : 2πr :314.0 원의 넓이 πr^2 : 7850
